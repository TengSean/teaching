# %%
s_y = 2011
temp = []

for y in range(0,1):
    s_m = 1
    for m in range(0, 12):
        s_d = 1
        for d in range(0, 20):
            temp.extend([str(s_y + y), str(s_m+ m), str(s_d + d)])
print(temp[:30])
# Out:
# ['2011', '1', '1', '2011', '1', '2', '2011', '1', '3', '2011', '1', '4', '2011', '1', '5', '2011', '1', '6', '2011', '1', '7', '2011', '1', '8', '2011', '1', '9', '2011', '1', '10']

# %%
result = []

for idx, t in enumerate(temp):
    if idx % 3 == 2:
        if len(temp[idx-1]) == 1:
            temp[idx-1] = '0' + temp[idx-1]
        if len(temp[idx]) == 1:
            temp[idx] = '0' + temp[idx]
        tt = temp[idx-2:idx+1]
#         print(tt)
        # string concat...
        # year month day concat by '-' notation. hint: join()
        pass
        # result append... hint: extend
        pass
# Out:
# 2011-01-01
# 2011-01-02
# 2011-01-03
# 2011-01-04
# 2011-01-05
# 2011-01-06
# 2011-01-07
# 2011-01-08
# 2011-01-09
# 2011-01-10
# 2011-01-11
# 2011-01-12
# 2011-01-13
# 2011-01-14
# 2011-01-15
# 2011-01-16
# 2011-01-17
# 2011-01-18
# 2011-01-19
# 2011-01-20
# 2011-02-01
# 2011-02-02
# 2011-02-03
# 2011-02-04
# 2011-02-05
# 2011-02-06
# 2011-02-07
# 2011-02-08
# 2011-02-09
# 2011-02-10
# 2011-02-11
# 2011-02-12
# 2011-02-13
# 2011-02-14
# 2011-02-15
# 2011-02-16
# 2011-02-17
# 2011-02-18
# 2011-02-19
# 2011-02-20
# 2011-03-01
# 2011-03-02
# 2011-03-03
# 2011-03-04
# 2011-03-05
# 2011-03-06
# 2011-03-07
# 2011-03-08
# 2011-03-09
# 2011-03-10
# 2011-03-11
# 2011-03-12
# 2011-03-13
# 2011-03-14
# 2011-03-15
# 2011-03-16
# 2011-03-17
# 2011-03-18
# 2011-03-19
# 2011-03-20
# 2011-04-01
# 2011-04-02
# 2011-04-03
# 2011-04-04
# 2011-04-05
# 2011-04-06
# 2011-04-07
# 2011-04-08
# 2011-04-09
# 2011-04-10
# 2011-04-11
# 2011-04-12
# 2011-04-13
# 2011-04-14
# 2011-04-15
# 2011-04-16
# ...

# %%
from datetime import datetime

for i in result:
    datetime.strptime( 'You should write something here...' , '%Y-%m-%d')
# Out:
# datetime.datetime(2011, 1, 3, 0, 0)
